# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Load the data
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  latitude  longitude  Wind_Speed  Land_Sea_Mask  \
# 0           0      36.0      26.00    7.338949       0.000000
# 1           1      36.0      26.25    7.329445       0.000839
# 2           2      36.0      26.50    7.301338       0.000397
# 3           3      36.0      26.75    7.314985       0.003494
# 4           4      36.0      27.00    7.058693       0.005402
#
#    distance_to_nearest_seaport  distance_to_nearest_transmittor   sosaline  \
# 0                   160.455323                       360.294858  39.292670
# 1                   145.510995                       338.489107  39.287334
# 2                   132.662391                       316.763420  39.276382
# 3                   122.570451                       295.135640  39.269196
# 4                   115.957248                       273.629146  39.268070
#
#    sea_height  wave_height
# 0   -0.568770        0.174
# 1   -0.561336        0.184
# 2   -0.555107        0.212
# 3   -0.553612        0.231
# 4   -0.554766        0.241

# %%
data.drop("Unnamed: 0",axis=1,inplace=True)

# %%
# Extract the coordinates from the data
data_coordinates = data[["latitude", "longitude"]]

# Extract the features to be used in AHP from the data
data_features = data.drop(["latitude", "longitude"], axis=1)

# Normalize the features using MinMaxScaler
scaler = MinMaxScaler()
data_norm = pd.DataFrame(scaler.fit_transform(data_features), columns=data_features.columns)

# Define the criteria weights
criteria_weights = np.array([0.317, 0.317, 0.167, 0.093, 0.048, 0.034, 0.024])

# Define the pairwise comparison matrix
pairwise_matrix = np.array([[1, 1, 3, 5, 7, 8, 9],
                            [1, 1, 3, 5, 7, 8, 9],
                            [1/3, 1/3, 1, 3, 5, 6, 7],
                            [1/5, 1/5, 1/3, 1, 3, 4, 5],
                            [1/7, 1/7, 1/5, 1/3, 1, 2, 3],
                            [1/8, 1/8, 1/6, 1/4, 1/2, 1, 2],
                            [1/9, 1/9, 1/7, 1/5, 1/3, 1/2, 1]])

# Normalize the pairwise comparison matrix to get the criteria weights
criteria_matrix = pairwise_matrix / pairwise_matrix.sum(axis=1, keepdims=True)

# Calculate the criteria weights by taking the row-wise means of the normalized pairwise comparison matrix
criteria_weights = criteria_matrix.mean(axis=1)

# Calculate the weighted sum for each location
weighted_sums = np.sum(criteria_weights * data_norm, axis=1)

# Normalize the weighted sums
weighted_sums_norm = weighted_sums / weighted_sums.max()

# Find the index of the location with the highest weighted sum
best_location_idx = np.argmax(weighted_sums_norm)

# Extract the latitude and longitude of the best location
best_location = data_coordinates.iloc[best_location_idx]

print("The best location is: Latitude {}, Longitude {}".format(best_location["latitude"], best_location["longitude"]))
# Out:
# The best location is: Latitude 31.25, Longitude 26.0

# %%
best_location
# Out:
# latitude     31.25
# longitude    26.00
# Name: 703, dtype: float64

# %%
weighted_sums_norm
# Out:
# 0      0.704809
# 1      0.696327
# 2      0.694160
# 3      0.689608
# 4      0.672620
#          ...
# 772    0.753143
# 773    0.749529
# 774    0.766117
# 775    0.766173
# 776    0.755220
# Length: 777, dtype: float64

# %%
top_10_locations = weighted_sums_norm.nlargest(10)

# %%
top_10_locations.index
# Out:
# Int64Index([703, 740, 704, 741, 705, 666, 742, 667, 629, 706], dtype='int64')

# %%
best_locations = data_coordinates.iloc[top_10_locations.index]

# %%
best_locations
# Out:
#      latitude  longitude
# 703     31.25      26.00
# 740     31.00      26.00
# 704     31.25      26.25
# 741     31.00      26.25
# 705     31.25      26.50
# 666     31.50      26.00
# 742     31.00      26.50
# 667     31.50      26.25
# 629     31.75      26.00
# 706     31.25      26.75

# %%
data_coordinates["sums"] = weighted_sums_norm
# Out:
# C:\Users\MustafAi\AppData\Local\Temp\ipykernel_6536\3577858177.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_coordinates["sums"] = weighted_sums_norm

# %%
data_coordinates
# Out:
#      latitude  longitude      sums
# 0        36.0      26.00  0.704809
# 1        36.0      26.25  0.696327
# 2        36.0      26.50  0.694160
# 3        36.0      26.75  0.689608
# 4        36.0      27.00  0.672620
# ..        ...        ...       ...
# 772      31.0      34.00  0.753143
# 773      31.0      34.25  0.749529
# 774      31.0      34.50  0.766117
# 775      31.0      34.75  0.766173
# 776      31.0      35.00  0.755220
#
# [777 rows x 3 columns]

# %%
top_20 = data_coordinates.loc[data_coordinates['latitude'] > 31.5].nlargest(20, 'sums')

# %%
top_20
# Out:
#      latitude  longitude      sums
# 629     31.75      26.00  0.913122
# 630     31.75      26.25  0.876192
# 371     33.50      26.25  0.861482
# 334     33.75      26.25  0.860229
# 370     33.50      26.00  0.858979
# 333     33.75      26.00  0.858710
# 297     34.00      26.25  0.855687
# 335     33.75      26.50  0.852528
# 298     34.00      26.50  0.850939
# 296     34.00      26.00  0.849079
# 372     33.50      26.50  0.845979
# 407     33.25      26.00  0.840907
# 408     33.25      26.25  0.837369
# 336     33.75      26.75  0.836581
# 299     34.00      26.75  0.835560
# 337     33.75      27.00  0.832066
# 444     33.00      26.00  0.830623
# 409     33.25      26.50  0.830108
# 631     31.75      26.50  0.829958
# 373     33.50      26.75  0.828795

# %%
import folium

# create a map centered on the Mediterranean Sea
map_center = [35, 25]
zoom_level = 5
m = folium.Map(location=map_center, zoom_start=zoom_level)

# add a marker for each location
for index, row in top_20.iterrows():
    if row['latitude'] > 32:
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f"Lat: {row['latitude']}, Lon: {row['longitude']}, Score: {row['sums']:.3f}",
            tooltip=row.name,
            icon=folium.Icon(color='green')
        ).add_to(m)

# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48a22030f979aab021d568834e469711 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48a22030f979aab021d568834e469711&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48a22030f979aab021d568834e469711 = L.map(
#                 &quot;map_48a22030f979aab021d568834e469711&quot;,
#                 {
#                     center: [35.0, 25.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7d682c6ec829240bff705c3872b84d9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_48a22030f979aab021d568834e469711);
#
#
#             var marker_ed03c463aae6cd43d0458d11b82ca32f = L.marker(
#                 [33.5, 26.25],
#                 {}
#             ).addTo(map_48a22030f979aab021d568834e469711);
#
#
#             var icon_8d36342bffc536a8b1335512fef8dc0a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ed03c463aae6cd43d0458d11b82ca32f.setIcon(icon_8d36342bffc536a8b1335512fef8dc0a);
#
#
#         var popup_1eeb425bc1572c677f7e62475816f2b2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af4835228f9c3df16bc32f4757d61381 = $(`&lt;div id=&quot;html_af4835228f9c3df16bc32f4757d61381&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lat: 33.5, Lon: 26.25, Score: 0.861&lt;/div&gt;`)[0];
#                 popup_1eeb425bc1572c677f7e62475816f2b2.setContent(html_af4835228f9c3df16bc32f4757d61381);
#
#
#
#         marker_ed03c463aae6cd43d0458d11b82ca32f.bindPopup(popup_1eeb425bc1572c677f7e62475816f2b2)
#         ;
#
#
#
#
#             marker_ed03c463aae6cd43d0458d11b82ca32f.bindTooltip(
#                 `&lt;div&gt;
#                      371
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3fb30fd5c2e2844134d407e1a6a5cf19 = L.marker(
#                 [33.75, 26.25],
#                 {}
#             ).addTo(map_48a22030f979aab021d568834e469711);
#
#
#             var icon_28a37fd74ac2d90e0f82c7e0688d1695 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3fb30fd5c2e2844134d407e1a6a5cf19.setIcon(icon_28a37fd74ac2d90e0f82c7e0688d1695);
#
#
#         var popup_5315d3cce43302e1ab7753b9a5dd114e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_33774dc81b49bed5f4a0e0dc451e6159 = $(`&lt;div id=&quot;html_33774dc81b49bed5f4a0e0dc451e6159&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lat: 33.75, Lon: 26.25, Score: 0.860&lt;/div&gt;`)[0];
#                 popup_5315d3cce43302e1ab7753b9a5dd114e.setContent(html_33774dc81b49bed5f4a0e0dc451e6159);
#
#
#
#         marker_3fb30fd5c2e2844134d407e1a6a5cf19.bindPopup(popup_5315d3cce43302e1ab7753b9a5dd114e)
#         ;
#
#
#
#
#             marker_3fb30fd5c2e2844134d407e1a6a5cf19.bindTooltip(
#                 `&lt;div&gt;
#                      334
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6b0242fccdcaeb0f93c5254dfb29ef2c = L.marker(
#                 [33.5, 26.0],
#                 {}
#             ).addTo(map_48a22030f979aab021d568834e469711);
#
#
#             var icon_15fb9547c0667f1b21c806001f1f452c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6b0242fccdcaeb0f93c5254dfb29ef2c.setIcon(icon_15fb9547c0667f1b21c806001f1f452c);
#
#
#         var popup_5cbca5e24426285fd644c2055baa7bc1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9e62243b84e7cdd72b4b089171f5b8cc = $(`&lt;div id=&quot;html_9e62243b84e7cdd72b4b089171f5b8cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lat: 33.5, Lon: 26.0, Score: 0.859&lt;/div&gt;`)[0];
#                 popup_5cbca5e24426285fd644c2055baa7bc1.setContent(html_9e62243b84e7cdd72b4b089171f5b8cc);
#
#
#
#         marker_6b0242fcc
