# %%
import pandas as pd

# %%
import csv

# Metin dosyasını oku ve verileri bir liste olarak depola
with open('landmask-windspeed-wave-len/si10.txt', 'r') as f:
    data = [line.strip().split('\t') for line in f.readlines()]

# %%
with open('t.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

# %%
wind_data = pd.read_csv("t.csv")

# %%
wind_data.head()
# Out:
#       time  latitude  longitude      si10
# 0  1079616      36.0      26.00  7.338949
# 1  1079616      36.0      26.25  7.329445
# 2  1079616      36.0      26.50  7.301338
# 3  1079616      36.0      26.75  7.314985
# 4  1079616      36.0      27.00  7.058693

# %%
with open('landmask-windspeed-wave-len/swh.txt', 'r') as f:
    data = [line.strip().split('\t') for line in f.readlines()]

# %%
with open('t.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

# %%
wave_data = pd.read_csv("t.csv")

# %%
wave_data
# Out:
#         time  latitude  longitude       swh
# 0    1079616      36.0      26.00  1.291396
# 1    1079616      36.0      26.25  1.283098
# 2    1079616      36.0      26.50  1.237679
# 3    1079616      36.0      26.75  1.103529
# 4    1079616      36.0      27.00  0.697890
# ..       ...       ...        ...       ...
# 772  1079616      31.0      34.00       NaN
# 773  1079616      31.0      34.25       NaN
# 774  1079616      31.0      34.50       NaN
# 775  1079616      31.0      34.75       NaN
# 776  1079616      31.0      35.00       NaN
#
# [777 rows x 4 columns]

# %%
with open('landmask-windspeed-wave-len/lsm.txt', 'r') as f:
    data = [line.strip().split('\t') for line in f.readlines()]

# %%
with open('t.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

# %%
land_data = pd.read_csv("t.csv")

# %%
wind_data["swh"] =wave_data["swh"]

# %%
wind_data["lsm"] = land_data["lsm"]

# %%
wind_data.dropna(inplace=True)

# %%
wind_data
# Out:
#         time  latitude  longitude      si10       swh       lsm
# 0    1079616     36.00      26.00  7.338949  1.291396  0.000000
# 1    1079616     36.00      26.25  7.329445  1.283098  0.000839
# 2    1079616     36.00      26.50  7.301338  1.237679  0.000397
# 3    1079616     36.00      26.75  7.314985  1.103529  0.003494
# 4    1079616     36.00      27.00  7.058693  0.697890  0.005402
# ..       ...       ...        ...       ...       ...       ...
# 347  1079616     33.75      29.50  6.861376  0.931040  0.000000
# 348  1079616     33.75      29.75  6.793059  0.917251  0.000000
# 349  1079616     33.75      30.00  6.692167  0.870613  0.000000
# 376  1079616     33.50      27.50  7.177050  0.936654  0.000000
# 377  1079616     33.50      27.75  7.156823  0.987194  0.000000
#
# [181 rows x 6 columns]

# %%
df = wind_data.rename(columns={'si10': 'Wind_Speed', 'swh': 'Wave_Height', 'lsm': 'Land_Sea_Mask'})

# %%
df.drop("time",axis=1,inplace=True)

# %%
df.head()
# Out:
#    latitude  longitude  Wind_Speed  Wave_Height  Land_Sea_Mask
# 0      36.0      26.00    7.338949     1.291396       0.000000
# 1      36.0      26.25    7.329445     1.283098       0.000839
# 2      36.0      26.50    7.301338     1.237679       0.000397
# 3      36.0      26.75    7.314985     1.103529       0.003494
# 4      36.0      27.00    7.058693     0.697890       0.005402

# %%
df.reset_index(drop=True, inplace=True)
df.index += 1

# %%
df.tail()
# Out:
#      latitude  longitude  Wind_Speed  Wave_Height  Land_Sea_Mask
# 177     33.75      29.50    6.861376     0.931040            0.0
# 178     33.75      29.75    6.793059     0.917251            0.0
# 179     33.75      30.00    6.692167     0.870613            0.0
# 180     33.50      27.50    7.177050     0.936654            0.0
# 181     33.50      27.75    7.156823     0.987194            0.0

# %%
df.to_csv("wind_land_wave.csv")
